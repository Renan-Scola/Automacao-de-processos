# %%
from selenium import webdriver
navegador = webdriver.Chrome()

# %%
import pandas as pd
contatos_df = pd.read_excel("ReprovadosRJ.xlsx")
display(contatos_df)
# Out:
#                          Pessoa      nome        Número  \
# 0     Renan Godoi Pereira Scola     Renan  5.511982e+12
# 1                   Renan Scola     Renan  5.511983e+12
# 2               Letícia Salgado   Letícia  5.511997e+12
# 3                Raphaela Scola  Raphaela  5.511950e+12
# 4                 Julia Menezes     Julia  5.511976e+12
# ...                         ...       ...           ...
# 7094                        NaN       NaN           NaN
# 7095                        NaN       NaN           NaN
# 7096                        NaN       NaN           NaN
# 7097                        NaN       NaN           NaN
# 7098                        NaN       NaN           NaN
#
#                                                Mensagem
# 0     Oiii!%20Tudo%20bem%3F%20%20%20J%C3%A1%20est%C3...
# 1     Oiii!%20Tudo%20bem%3F%20%20%20J%C3%A1%20est%C3...
# 2     Oiii!%20Tudo%20bem%3F%20%20%20J%C3%A1%20est%C3...
# 3     Oiii!%20Tudo%20bem%3F%20%20%20J%C3%A1%20est%C3...
# 4     Oiii!%20Tudo%20bem%3F%20%20%20J%C3%A1%20est%C3...
# ...                                                 ...
# 7094                                                ola
# 7095                                                ola
# 7096                                                ola
# 7097                                                ola
# 7098                                                ola
#
# [7099 rows x 4 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

navegador = webdriver.Chrome()
navegador.get("https://web.whatsapp.com/")

while len(navegador.find_elements_by_id("side")) < 1: 
    time.sleep(1)

for i, mensagem in enumerate(contatos_df['Mensagem']):
    pessoa = contatos_df.loc[i, "Pessoa"]
    numero = contatos_df.loc[i, "Número"]
    texto = "Olá {pessoa}! {mensagem}"
    link = f"https://web.whatsapp.com/send?phone={numero}&text={texto}"
    navegador.get(link)
    while len(navegador.find_elements_by_id("side")) < 1 :
        time.sleep(1)
    
    navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[2]').send_keys(Keys.ENTER)
    time.sleep(10)
# Out:
# C:\Users\novo\AppData\Local\Temp\ipykernel_4812\1190983790.py:8: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   while len(navegador.find_elements_by_id("side")) < 1:
# C:\Users\novo\AppData\Local\Temp\ipykernel_4812\1190983790.py:17: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   while len(navegador.find_elements_by_id("side")) < 1 :
# C:\Users\novo\AppData\Local\Temp\ipykernel_4812\1190983790.py:20: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[2]').send_keys(Keys.ENTER)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [8], in <cell line: 11>()
#      17 while len(navegador.find_elements_by_id("side")) < 1 :
#      18     time.sleep(1)
# ---> 20 navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[2]').send_keys(Keys.ENTER)
#      21 time.sleep(10)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:526, in WebDriver.find_element_by_xpath(self, xpath)
#     504 """
#     505 Finds an element by xpath.
#     506
#    (...)
#     519         element = driver.find_element_by_xpath('//div/td[1]')
#     520 """
#     521 warnings.warn(
#     522     "find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead",
#     523     DeprecationWarning,
#     524     stacklevel=2,
#     525 )
# --> 526 return self.find_element(by=By.XPATH, value=xpath)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[2]"}
#   (Session info: chrome=102.0.5005.115)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0074D953+2414931]
# 	Ordinal0 [0x006DF5E1+1963489]
# 	Ordinal0 [0x005CC6B8+837304]
# 	Ordinal0 [0x005F9500+1021184]
# 	Ordinal0 [0x005F979B+1021851]
# 	Ordinal0 [0x00626502+1205506]
# 	Ordinal0 [0x006144E4+1131748]
# 	Ordinal0 [0x00624812+1198098]
# 	Ordinal0 [0x006142B6+1131190]
# 	Ordinal0 [0x005EE860+976992]
# 	Ordinal0 [0x005EF756+980822]
# 	GetHandleVerifier [0x009BCC62+2510274]
# 	GetHandleVerifier [0x009AF760+2455744]
# 	GetHandleVerifier [0x007DEABA+551962]
# 	GetHandleVerifier [0x007DD916+547446]
# 	Ordinal0 [0x006E5F3B+1990459]
# 	Ordinal0 [0x006EA898+2009240]
# 	Ordinal0 [0x006EA985+2009477]
# 	Ordinal0 [0x006F3AD1+2046673]
# 	BaseThreadInitThunk [0x75DFFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x770B7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x770B7A6E+238]
